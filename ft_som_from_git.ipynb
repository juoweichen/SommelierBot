# %%
import os
import math
import random
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import matplotlib.animation as animation

# %%
dataset_path = 'winequality-red.csv'

try:
    wine_data = pd.read_csv(dataset_path, sep=';')
except FileNotFoundError:
    print('[-] Set `dataset_path` with correct value')

# %% [markdown]
# ----------------------------------
# # V.1 Exploring the green reds

# %% [markdown]
# ### a) Write a function that will plot a scatterplot matrix of your red wine data

# %%
def plot_scatter_matrix(wine_data, good_threshold, bad_threshold, save_plot=False):
    """
    Plots a scatterplot matrix of data. Samples with quality over `good_threshold`
    are plotted as one color and samples below `bad_threshold` as another.

    :param pd.DataFrame wine_data:
    :param int good_threshold:
    :param int bad_threshold:

    :returns: result matplotlib.pyplot.figure object
    """
    num_samples, num_features = wine_data.shape

    fig, axes = plt.subplots(nrows=num_features,
                             ncols=num_features, figsize=(18,18))
    fig.subplots_adjust(hspace=0, wspace=0)
    
    for ax in axes.flat:
        ax.xaxis.set_visible(False)
        ax.yaxis.set_visible(False)
    
    feature_names = wine_data.columns
    for i, label in enumerate(feature_names):
        axes[i, i].annotate(label, (0.5, 0.5), xycoords='axes fraction',
                            ha='center', va='center')
    
    good_wines = wine_data[(wine_data['quality'] > good_threshold)]
    bad_wines = wine_data[(wine_data['quality'] < bad_threshold)]
    
    for i in range(num_features):
        for j in range(i + 1, num_features):
            axes[i, j].scatter(good_wines.iloc[:, j], good_wines.iloc[:, i], c=['g'], marker='.')
            axes[i, j].scatter(bad_wines.iloc[:, j], bad_wines.iloc[:, i], c=['r'], marker='.')
            axes[j, i].scatter(good_wines.iloc[:, i], good_wines.iloc[:, j], c=['g'], marker='.')
            axes[j, i].scatter(bad_wines.iloc[:, i], bad_wines.iloc[:, j], c=['r'], marker='.')

    if save_plot:
        plt.savefig('./scatterplot-matrix.png')
    
    return fig

# %%
fig = plot_scatter_matrix(wine_data, 7, 4, True)
plt.show(fig)

# %% [markdown]
# ### b) Which factors do you think will be most useful to your perceptron for distinguishing high quality vs. low quality wines? Why?

# %% [markdown]
# Perceptron, being a linear model, works best on linearly separable data.
#
# - **'alcohol'**, **'pH'**, **'sulphates'** look like good features for classification;
# - **'density'**, **'chlorides'** are bad features and most likely won't help;

# %% [markdown]
# ----------------------------------------------------------
# # V.2 Learning to perceptron

# %% [markdown]
# ### a) & b) Implementing Perceptron
# - Implement Rosenblatt perceptron with randomly initialized weights and bias, heaviside step activation function
# - Train your perceptron on 2 chemical factors (for example, alcohol and pH) and only use wines with a score of 8 or higher and wines with a score of 3 or lower

# %%
# Take the wine as good, if it's quality > 5
wine_data = wine_data.assign(goodness=pd.Series(wine_data['quality'] > 5))

# selecting the subset from `wine_data`
# only use wines with a score of 8 or higher and wines with a score of 3 or lower
features = ['pH', 'alcohol', 'quality', 'goodness']
selected_wine_data = wine_data[(wine_data['quality'] > 7) | (wine_data['quality'] < 4)][features]
selected_wine_data = selected_wine_data.reset_index(drop=True)

X = selected_wine_data.loc[:, ['pH', 'alcohol']]
Y = selected_wine_data['goodness'].values

print('{} samples selected:\n'.format(selected_wine_data.shape[0]))
print(selected_wine_data)
# Out:
# 28 samples selected:
#
#       pH  alcohol  quality  goodness
# 0   3.35    12.80        8      True
# 1   3.23    12.60        8      True
# 2   3.56    12.90        8      True
# 3   2.88     9.80        8      True
# 4   3.22    13.40        8      True
# 5   3.25     9.00        3     False
# 6   3.15    11.70        8      True
# 7   3.15    11.00        8      True
# 8   3.15    11.00        8      True
# 9   3.16     8.40        3     False
# 10  3.72    14.00        8      True
# 11  3.63    10.70        3     False
# 12  3.46    12.70        8      True
# 13  3.38     9.90        3     False
# 14  3.48    11.00        3     False
# 15  3.21    12.50        8      True
# 16  2.98    11.80        8      True
# 17  3.20    13.10        8      True
# 18  3.35    11.70        8      True
# 19  3.50    14.00        8      True
# 20  3.50    10.90        3     False
# 21  3.32     9.80        3     False
# 22  3.23    10.00        8      True
# 23  3.23    11.30        8      True
# 24  3.31     9.70        3     False
# 25  3.40    10.20        3     False
# 26  3.55     9.95        3     False
# 27  3.24    11.40        8      True

# %%
def ft_dot(a, b):
    """
    Dot product of two sequences of numbers. Both arguments have to
    be of equal length.
    
    :param np.array a:
    :param np.array b:
    """

    if len(a) != len(b):
        raise ValueError('arguments have different length')

    result = 0
    for i in range(len(a)):
        result += a[i] * b[i]
    
    return result


def array_init(shape, mode='rand'):
    """
    :param shape: an int or tuple, shape of the array to init
    :param mode: 'rand' | 'zeros' | 'ones'
    """
    
    if mode not in ('rand', 'zeros', 'ones'):
        raise ValueError('invalid mode')
    
    new_shape = shape
    if isinstance(shape, int):
        new_shape = (shape, 1)
    
    if isinstance(shape, tuple) and len(shape) == 1:
        new_shape = (shape[0], 1)
    
    base_dict = {}
    for i in range(new_shape[1]):
        if mode == 'rand':
            base_dict[i] = [0.0001 * random.uniform(-1, 1) for i in range(new_shape[0])]
        elif mode == 'zeros':
            base_dict[i] = new_shape[0] * [0.0]
        elif mode == 'ones':
            base_dict[i] = new_shape[0] * [1.0]
    
    df = pd.DataFrame.from_dict(base_dict)
    
    if isinstance(shape, int) or isinstance(shape, tuple) and len(shape) == 1:
        return df.values.squeeze()
    return df.values

# %%
class Perceptron:
    
    def __init__(self, lr):
        self.W = None
        self.lr = lr
        self.performance = list()
    
    def _net_input(self, X):
        """
        Linear model output: y = W.T * X + b
        """
        return ft_dot(self.W[1:], X) + self.W[0]
    
    def predict(self, X):
        """
        Mapping the net input to binary class value using unit (heaviside) step function
        """
        return 1 if self._net_input(X) > 0.0 else 0
    
    def evaluate_accuracy(self, X, y):
        num_correct = 0

        for xi, yi in zip(X, y):
            num_correct += int(self.predict(xi) == int(yi))
        
        accuracy = num_correct / len(y)
        print('[.] Model accuracy: {0:.3f}'.format(accuracy))
        
        return accuracy
    
    def _train_epoch(self, X, y, epoch, verbose):
        epoch_errors = 0

        for xi, yi in zip(X, y):
            update = self.lr * (yi - self.predict(xi))
            self.W[0] += update
            self.W[1:] += update * xi
            epoch_errors += int(update != 0.0)

        if verbose and epoch % 10 == 0:
            print('Epoch {}: {} errors'.format(epoch, epoch_errors))
        self.performance.append((epoch, epoch_errors, self.W[1:], self.W[0]))
        
        return epoch_errors
    
    def train(self, X, y, epochs, verbose=False, seed=None):
        if epochs < 0:
            raise ValueError('invalid number of training epochs')

        if seed:
            random.seed(seed)

        if self.W is None:
            self.W = [0.0001 * random.uniform(-1, 1) for i in range(X.shape[1] + 1)]

        epoch = 0
        while True:
            epoch_errors = self._train_epoch(X, y, epoch, verbose)
            epoch += 1
            if epochs != 0 and epoch == epochs:
                break
            elif epochs == 0 and epoch_errors == 0:
                break
        
        return self.performance

# %%
p = Perceptron(lr=0.005)

train_stats = p.train(X.values, Y, 0, verbose=True, seed=1699)
# Out:
# Epoch 0: 13 errors
# Epoch 10: 7 errors
# Epoch 20: 2 errors
# Epoch 30: 8 errors
# Epoch 40: 7 errors
# Epoch 50: 4 errors
# Epoch 60: 2 errors
# Epoch 70: 2 errors
# Epoch 80: 2 errors
# Epoch 90: 4 errors
# Epoch 100: 6 errors
# Epoch 110: 2 errors
# Epoch 120: 2 errors
# Epoch 130: 6 errors
# Epoch 140: 2 errors
# Epoch 150: 2 errors
# Epoch 160: 6 errors
# Epoch 170: 2 errors
# Epoch 180: 6 errors
# Epoch 190: 6 errors
# Epoch 200: 6 errors
# Epoch 210: 6 errors
# Epoch 220: 6 errors
# Epoch 230: 6 errors
# Epoch 240: 7 errors
# Epoch 250: 7 errors
# Epoch 260: 4 errors
# Epoch 270: 4 errors
# Epoch 280: 4 errors
# Epoch 290: 4 errors
# Epoch 300: 4 errors
# Epoch 310: 4 errors
# Epoch 320: 4 errors
# Epoch 330: 4 errors
# Epoch 340: 4 errors
# Epoch 350: 4 errors
# Epoch 360: 4 errors
# Epoch 370: 4 errors
# Epoch 380: 4 errors
# Epoch 390: 4 errors
# Epoch 400: 4 errors
# Epoch 410: 4 errors
# Epoch 420: 4 errors
# Epoch 430: 4 errors
# Epoch 440: 4 errors
# Epoch 450: 4 errors
# Epoch 460: 4 errors
# Epoch 470: 4 errors
# Epoch 480: 4 errors
# Epoch 490: 4 errors
# Epoch 500: 4 errors
# Epoch 510: 4 errors
# Epoch 520: 4 errors
# Epoch 530: 4 errors
# Epoch 540: 4 errors
# Epoch 550: 4 errors
# Epoch 560: 4 errors
# Epoch 570: 4 errors
# Epoch 580: 4 errors
# Epoch 590: 4 errors
# Epoch 600: 4 errors
# Epoch 610: 4 errors
# Epoch 620: 4 errors
# Epoch 630: 4 errors
# Epoch 640: 4 errors
# Epoch 650: 4 errors
# Epoch 660: 2 errors
# Epoch 670: 2 errors
# Epoch 680: 2 errors
# Epoch 690: 2 errors
# Epoch 700: 4 errors
# Epoch 710: 2 errors
# Epoch 720: 2 errors
# Epoch 730: 2 errors
# Epoch 740: 2 errors
# Epoch 750: 2 errors
# Epoch 760: 2 errors
# Epoch 770: 2 errors
# Epoch 780: 2 errors
# Epoch 790: 2 errors
# Epoch 800: 2 errors
# Epoch 810: 2 errors
# Epoch 820: 2 errors
# Epoch 830: 2 errors
# Epoch 840: 2 errors
# Epoch 850: 2 errors
# Epoch 860: 2 errors
# Epoch 870: 2 errors
# Epoch 880: 2 errors
# Epoch 890: 2 errors
# Epoch 900: 2 errors
# Epoch 910: 2 errors
# Epoch 920: 2 errors
# Epoch 930: 2 errors
# Epoch 940: 1 errors
# Epoch 950: 2 errors
# Epoch 960: 2 errors
# Epoch 970: 2 errors
# Epoch 980: 2 errors
# Epoch 990: 1 errors
# Epoch 1000: 2 errors
# Epoch 1010: 2 errors
# Epoch 1020: 2 errors
# Epoch 1030: 2 errors
# Epoch 1040: 1 errors
# Epoch 1050: 2 errors
# Epoch 1060: 2 errors
# Epoch 1070: 2 errors
# Epoch 1080: 2 errors
# Epoch 1090: 1 errors
# Epoch 1100: 2 errors
# Epoch 1110: 2 errors
# Epoch 1120: 2 errors
# Epoch 1130: 2 errors
# Epoch 1140: 1 errors
# Epoch 1150: 2 errors
# Epoch 1160: 2 errors
# Epoch 1170: 2 errors
# Epoch 1180: 2 errors
# Epoch 1190: 2 errors
# Epoch 1200: 2 errors
# Epoch 1210: 1 errors
# Epoch 1220: 2 errors
# Epoch 1230: 2 errors
# Epoch 1240: 2 errors
# Epoch 1250: 2 errors
# Epoch 1260: 2 errors
# Epoch 1270: 2 errors
# Epoch 1280: 2 errors
# Epoch 1290: 2 errors
# Epoch 1300: 2 errors
# Epoch 1310: 2 errors
# Epoch 1320: 2 errors
# Epoch 1330: 2 errors
# Epoch 1340: 2 errors
# Epoch 1350: 2 errors
# Epoch 1360: 2 errors
# Epoch 1370: 2 errors
# Epoch 1380: 2 errors
# Epoch 1390: 2 errors
# Epoch 1400: 2 errors
# Epoch 1410: 2 errors
# Epoch 1420: 2 errors
# Epoch 1430: 2 errors
# Epoch 1440: 2 errors
# Epoch 1450: 2 errors
# Epoch 1460: 2 errors
# Epoch 1470: 2 errors
# Epoch 1480: 2 errors
# Epoch 1490: 2 errors
# Epoch 1500: 2 errors
# Epoch 1510: 2 errors
# Epoch 1520: 2 errors
# Epoch 1530: 2 errors
# Epoch 1540: 2 errors
# Epoch 1550: 2 errors
# Epoch 1560: 2 errors
# Epoch 1570: 2 errors
# Epoch 1580: 2 errors
# Epoch 1590: 2 errors
# Epoch 1600: 2 errors
# Epoch 1610: 2 errors
# Epoch 1620: 2 errors
# Epoch 1630: 2 errors
# Epoch 1640: 1 errors
# Epoch 1650: 2 errors
# Epoch 1660: 2 errors
# Epoch 1670: 2 errors
# Epoch 1680: 2 errors
# Epoch 1690: 2 errors
# Epoch 1700: 2 errors
# Epoch 1710: 2 errors
# Epoch 1720: 2 errors
# Epoch 1730: 2 errors
# Epoch 1740: 2 errors
# Epoch 1750: 2 errors
# Epoch 1760: 2 errors
# Epoch 1770: 2 errors
# Epoch 1780: 2 errors
# Epoch 1790: 2 errors
# Epoch 1800: 2 errors
# Epoch 1810: 2 errors
# Epoch 1820: 2 errors
# Epoch 1830: 2 errors
# Epoch 1840: 2 errors
# Epoch 1850: 2 errors
# Epoch 1860: 2 errors
# Epoch 1870: 2 errors
# Epoch 1880: 2 errors
# Epoch 1890: 2 errors
# Epoch 1900: 2 errors
# Epoch 1910: 2 errors
# Epoch 1920: 2 errors
# Epoch 1930: 2 errors
# Epoch 1940: 2 errors
# Epoch 1950: 2 errors
# Epoch 1960: 2 errors
# Epoch 1970: 2 errors
# Epoch 1980: 2 errors
# Epoch 1990: 2 errors
# Epoch 2000: 2 errors
# Epoch 2010: 2 errors
# Epoch 2020: 2 errors
# Epoch 2030: 2 errors
# Epoch 2040: 2 errors
# Epoch 2050: 2 errors
# Epoch 2060: 2 errors
# Epoch 2070: 2 errors
# Epoch 2080: 2 errors
# Epoch 2090: 2 errors
# Epoch 2100: 2 errors
# Epoch 2110: 2 errors
# Epoch 2120: 2 errors
# Epoch 2130: 2 errors
# Epoch 2140: 2 errors
# Epoch 2150: 2 errors
# Epoch 2160: 2 errors
# Epoch 2170: 2 errors
# Epoch 2180: 2 errors
# Epoch 2190: 2 errors
# Epoch 2200: 2 errors
# Epoch 2210: 2 errors
# Epoch 2220: 2 errors
# Epoch 2230: 2 errors
# Epoch 2240: 2 errors
# Epoch 2250: 2 errors
# Epoch 2260: 2 errors
# Epoch 2270: 2 errors
# Epoch 2280: 2 errors
# Epoch 2290: 2 errors
# Epoch 2300: 2 errors
# Epoch 2310: 2 errors
# Epoch 2320: 2 errors
# Epoch 2330: 2 errors
# Epoch 2340: 2 errors
# Epoch 2350: 2 errors
# Epoch 2360: 2 errors
# Epoch 2370: 2 errors
# Epoch 2380: 2 errors
# Epoch 2390: 2 errors
# Epoch 2400: 2 errors
# Epoch 2410: 1 errors
# Epoch 2420: 2 errors
# Epoch 2430: 2 errors
# Epoch 2440: 2 errors
# Epoch 2450: 2 errors
# Epoch 2460: 2 errors
# Epoch 2470: 2 errors
# Epoch 2480: 2 errors
# Epoch 2490: 2 errors
# Epoch 2500: 2 errors
# Epoch 2510: 2 errors
# Epoch 2520: 1 errors
# Epoch 2530: 2 errors
# Epoch 2540: 2 errors
# Epoch 2550: 2 errors
# Epoch 2560: 2 errors
# Epoch 2570: 2 errors
# Epoch 2580: 2 errors
# Epoch 2590: 2 errors
# Epoch 2600: 2 errors
# Epoch 2610: 2 errors
# Epoch 2620: 2 errors
# Epoch 2630: 1 errors
# Epoch 2640: 2 errors
# Epoch 2650: 2 errors
# Epoch 2660: 2 errors
# Epoch 2670: 2 errors
# Epoch 2680: 2 errors
# Epoch 2690: 2 errors
# Epoch 2700: 2 errors
# Epoch 2710: 2 errors
# Epoch 2720: 2 errors
# Epoch 2730: 2 errors
# Epoch 2740: 1 errors
# Epoch 2750: 2 errors
# Epoch 2760: 2 errors
# Epoch 2770: 2 errors
# Epoch 2780: 2 errors
# Epoch 2790: 2 errors
# Epoch 2800: 2 errors
# Epoch 2810: 2 errors
# Epoch 2820: 2 errors
# Epoch 2830: 2 errors
# Epoch 2840: 2 errors
# Epoch 2850: 1 errors
# Epoch 2860: 2 errors
# Epoch 2870: 2 errors
# Epoch 2880: 2 errors
# Epoch 2890: 2 errors
# Epoch 2900: 2 errors
# Epoch 2910: 2 errors
# Epoch 2920: 2 errors
# Epoch 2930: 2 errors
# Epoch 2940: 2 errors
# Epoch 2950: 2 errors
# Epoch 2960: 1 errors
# Epoch 2970: 2 errors
# Epoch 2980: 2 errors
# Epoch 2990: 2 errors
# Epoch 3000: 2 errors
# Epoch 3010: 2 errors
# Epoch 3020: 2 errors
# Epoch 3030: 2 errors
# Epoch 3040: 2 errors
# Epoch 3050: 2 errors
# Epoch 3060: 2 errors
# Epoch 3070: 2 errors
# Epoch 3080: 2 errors
# Epoch 3090: 2 errors
# Epoch 3100: 2 errors
# Epoch 3110: 2 errors
# Epoch 3120: 2 errors
# Epoch 3130: 2 errors
# Epoch 3140: 2 errors
# Epoch 3150: 2 errors
# Epoch 3160: 1 errors
# Epoch 3170: 2 errors
# Epoch 3180: 2 errors
# Epoch 3190: 2 errors
# Epoch 3200: 2 errors
# Epoch 3210: 2 errors
# Epoch 3220: 2 errors
# Epoch 3230: 2 errors
# Epoch 3240: 2 errors
# Epoch 3250: 2 errors
# Epoch 3260: 2 errors
# Epoch 3270: 2 errors
# Epoch 3280: 2 errors
# Epoch 3290: 2 errors
# Epoch 3300: 2 errors
# Epoch 3310: 2 errors
# Epoch 3320: 2 errors
# Epoch 3330: 2 errors
# Epoch 3340: 2 errors
# Epoch 3350: 2 errors
# Epoch 3360: 2 errors
# Epoch 3370: 2 errors
# Epoch 3380: 2 errors
# Epoch 3390: 2 errors
# Epoch 3400: 2 errors
# Epoch 3410: 2 errors
# Epoch 3420: 2 errors
# Epoch 3430: 2 errors
# Epoch 3440: 2 errors
# Epoch 3450: 2 errors
# Epoch 3460: 2 errors
# Epoch 3470: 2 errors
# Epoch 3480: 2 errors
# Epoch 3490: 2 errors
# Epoch 3500: 2 errors
# Epoch 3510: 2 errors
# Epoch 3520: 2 errors
# Epoch 3530: 2 errors
# Epoch 3540: 2 errors
# Epoch 3550: 2 errors
# Epoch 3560: 2 errors
# Epoch 3570: 2 errors
# Epoch 3580: 1 errors
# Epoch 3590: 2 errors
# Epoch 3600: 2 errors
# Epoch 3610: 2 errors
# Epoch 3620: 2 errors
# Epoch 3630: 2 errors
# Epoch 3640: 2 errors
# Epoch 3650: 2 errors
# Epoch 3660: 2 errors
# Epoch 3670: 2 errors
# Epoch 3680: 2 errors
# Epoch 3690: 2 errors
# Epoch 3700: 2 errors
# Epoch 3710: 2 errors
# Epoch 3720: 2 errors
# Epoch 3730: 1 errors
# Epoch 3740: 2 errors
# Epoch 3750: 2 errors
# Epoch 3760: 2 errors
# Epoch 3770: 2 errors
# Epoch 3780: 2 errors
# Epoch 3790: 2 errors
# Epoch 3800: 2 errors
# Epoch 3810: 2 errors
# Epoch 3820: 2 errors
# Epoch 3830: 2 errors
# Epoch 3840: 2 errors
# Epoch 3850: 2 errors
# Epoch 3860: 2 errors
# Epoch 3870: 2 errors
# Epoch 3880: 1 errors
# Epoch 3890: 2 errors
# Epoch 3900: 2 errors
# Epoch 3910: 2 errors
# Epoch 3920: 2 errors
# Epoch 3930: 2 errors
# Epoch 3940: 2 errors
# Epoch 3950: 2 errors
# Epoch 3960: 2 errors
# Epoch 3970: 2 errors
# Epoch 3980: 2 errors
# Epoch 3990: 2 errors
# Epoch 4000: 2 errors
# Epoch 4010: 2 errors
# Epoch 4020: 2 errors
# Epoch 4030: 1 errors
# Epoch 4040: 2 errors
# Epoch 4050: 2 errors
# Epoch 4060: 2 errors
# Epoch 4070: 2 errors
# Epoch 4080: 2 errors
# Epoch 4090: 2 errors
# Epoch 4100: 2 errors
# Epoch 4110: 2 errors
# Epoch 4120: 2 errors
# Epoch 4130: 2 errors
# Epoch 4140: 2 errors
# Epoch 4150: 2 errors
# Epoch 4160: 2 errors
# Epoch 4170: 2 errors
# Epoch 4180: 1 errors
# Epoch 4190: 2 errors
# Epoch 4200: 2 errors
# Epoch 4210: 2 errors
# Epoch 4220: 2 errors
# Epoch 4230: 2 errors
# Epoch 4240: 2 errors
# Epoch 4250: 2 errors
# Epoch 4260: 2 errors
# Epoch 4270: 2 errors
# Epoch 4280: 2 errors
# Epoch 4290: 2 errors
# Epoch 4300: 2 errors
# Epoch 4310: 2 errors
# Epoch 4320: 2 errors
# Epoch 4330: 2 errors
# Epoch 4340: 2 errors
# Epoch 4350: 2 errors
# Epoch 4360: 2 errors
# Epoch 4370: 2 errors
# Epoch 4380: 2 errors
# Epoch 4390: 2 errors
# Epoch 4400: 2 errors
# Epoch 4410: 2 errors
# Epoch 4420: 2 errors
# Epoch 4430: 2 errors
# Epoch 4440: 2 errors
# Epoch 4450: 2 errors
# Epoch 4460: 2 errors
# Epoch 4470: 2 errors
# Epoch 4480: 2 errors
# Epoch 4490: 2 errors
# Epoch 4500: 2 errors
# Epoch 4510: 2 errors
# Epoch 4520: 2 errors
# Epoch 4530: 2 errors
# Epoch 4540: 2 errors
# Epoch 4550: 2 errors
# Epoch 4560: 2 errors
# Epoch 4570: 2 errors
# Epoch 4580: 2 errors
# Epoch 4590: 2 errors
# Epoch 4600: 2 errors
# Epoch 4610: 2 errors
# Epoch 4620: 2 errors
# Epoch 4630: 2 errors
# Epoch 4640: 2 errors
# Epoch 4650: 1 errors
# Epoch 4660: 2 errors
# Epoch 4670: 2 errors
# Epoch 4680: 2 errors
# Epoch 4690: 2 errors
# Epoch 4700: 2 errors
# Epoch 4710: 2 errors
# Epoch 4720: 2 errors
# Epoch 4730: 2 errors
# Epoch 4740: 2 errors
# Epoch 4750: 2 errors
# Epoch 4760: 2 errors
# Epoch 4770: 2 errors
# Epoch 4780: 2 errors
# Epoch 4790: 2 errors
# Epoch 4800: 1 errors
# Epoch 4810: 2 errors
# Epoch 4820: 2 errors
# Epoch 4830: 2 errors
# Epoch 4840: 2 errors
# Epoch 4850: 2 errors
# Epoch 4860: 2 errors
# Epoch 4870: 2 errors
# Epoch 4880: 2 errors
# Epoch 4890: 2 errors
# Epoch 4900: 2 errors
# Epoch 4910: 2 errors
# Epoch 4920: 2 errors
# Epoch 4930: 2 errors
# Epoch 4940: 2 errors
# Epoch 4950: 1 errors
# Epoch 4960: 2 errors
# Epoch 4970: 2 errors
# Epoch 4980: 2 errors
# Epoch 4990: 2 errors
# Epoch 5000: 2 errors
# Epoch 5010: 2 errors
# Epoch 5020: 2 errors
# Epoch 5030: 2 errors
# Epoch 5040: 2 errors
# Epoch 5050: 2 errors
# Epoch 5060: 2 errors
# Epoch 5070: 2 errors
# Epoch 5080: 2 errors
# Epoch 5090: 2 errors
# Epoch 5100: 1 errors
# Epoch 5110: 2 errors
# Epoch 5120: 2 errors
# Epoch 5130: 2 errors
# Epoch 5140: 2 errors
# Epoch 5150: 2 errors
# Epoch 5160: 2 errors
# Epoch 5170: 2 errors
# Epoch 5180: 2 errors
# Epoch 5190: 2 errors
# Epoch 5200: 2 errors
# Epoch 5210: 2 errors
# Epoch 5220: 2 errors
# Epoch 5230: 2 errors
# Epoch 5240: 2 errors
# Epoch 5250: 1 errors
# Epoch 5260: 2 errors
# Epoch 5270: 2 errors
# Epoch 5280: 2 errors
# Epoch 5290: 2 errors
# Epoch 5300: 2 errors
# Epoch 5310: 2 errors
# Epoch 5320: 2 errors
# Epoch 5330: 2 errors
# Epoch 5340: 2 errors
# Epoch 5350: 2 errors
# Epoch 5360: 2 errors
# Epoch 5370: 2 errors
# Epoch 5380: 2 errors
# Epoch 5390: 2 errors
# Epoch 5400: 2 errors
# Epoch 5410: 2 errors
# Epoch 5420: 2 errors
# Epoch 5430: 2 errors
# Epoch 5440: 2 errors
# Epoch 5450: 2 errors
# Epoch 5460: 2 errors
# Epoch 5470: 2 errors
# Epoch 5480: 2 errors
# Epoch 5490: 2 errors
# Epoch 5500: 2 errors
# Epoch 5510: 2 errors
# Epoch 5520: 2 errors
# Epoch 5530: 2 errors
# Epoch 5540: 2 errors
# Epoch 5550: 2 errors
# Epoch 5560: 2 errors
# Epoch 5570: 2 errors
# Epoch 5580: 2 errors
# Epoch 5590: 2 errors
# Epoch 5600: 2 errors
# Epoch 5610: 2 errors
# Epoch 5620: 2 errors
# Epoch 5630: 2 errors
# Epoch 5640: 2 errors
# Epoch 5650: 2 errors
# Epoch 5660: 2 errors
# Epoch 5670: 2 errors
# Epoch 5680: 2 errors
# Epoch 5690: 2 errors
# Epoch 5700: 2 errors
# Epoch 5710: 2 errors
# Epoch 5720: 1 errors
# Epoch 5730: 2 errors
# Epoch 5740: 2 errors
# Epoch 5750: 2 errors
# Epoch 5760: 2 errors
# Epoch 5770: 2 errors
# Epoch 5780: 2 errors
# Epoch 5790: 2 errors
# Epoch 5800: 2 errors
# Epoch 5810: 2 errors
# Epoch 5820: 2 errors
# Epoch 5830: 2 errors
# Epoch 5840: 2 errors
# Epoch 5850: 2 errors
# Epoch 5860: 2 errors
# Epoch 5870: 1 errors
# Epoch 5880: 2 errors
# Epoch 5890: 2 errors
# Epoch 5900: 2 errors
# Epoch 5910: 2 errors
# Epoch 5920: 2 errors
# Epoch 5930: 2 errors
# Epoch 5940: 2 errors
# Epoch 5950: 2 errors
# Epoch 5960: 2 errors
# Epoch 5970: 2 errors
# Epoch 5980: 2 errors
# Epoch 5990: 2 errors
# Epoch 6000: 2 errors
# Epoch 6010: 2 errors
# Epoch 6020: 1 errors
# Epoch 6030: 2 errors
# Epoch 6040: 2 errors
# Epoch 6050: 2 errors
# Epoch 6060: 2 errors
# Epoch 6070: 2 errors
# Epoch 6080: 2 errors
# Epoch 6090: 2 errors
# Epoch 6100: 2 errors
# Epoch 6110: 2 errors
# Epoch 6120: 2 errors
# Epoch 6130: 2 errors
# Epoch 6140: 2 errors
# Epoch 6150: 2 errors
# Epoch 6160: 2 errors
# Epoch 6170: 1 errors
# Epoch 6180: 2 errors
# Epoch 6190: 2 errors
# Epoch 6200: 2 errors
# Epoch 6210: 2 errors
# Epoch 6220: 2 errors
# Epoch 6230: 2 errors
# Epoch 6240: 2 errors
# Epoch 6250: 2 errors
# Epoch 6260: 2 errors
# Epoch 6270: 2 errors
# Epoch 6280: 2 errors
# Epoch 6290: 2 errors
# Epoch 6300: 2 errors
# Epoch 6310: 2 errors
# Epoch 6320: 1 errors
# Epoch 6330: 2 errors
# Epoch 6340: 2 errors
# Epoch 6350: 2 errors
# Epoch 6360: 2 errors
# Epoch 6370: 2 errors
# Epoch 6380: 2 errors
# Epoch 6390: 2 errors
# Epoch 6400: 2 errors
# Epoch 6410: 2 errors
# Epoch 6420: 2 errors
# Epoch 6430: 2 errors
# Epoch 6440: 2 errors
# Epoch 6450: 2 errors
# Epoch 6460: 2 errors
# Epoch 6470: 1 errors
# Epoch 6480: 2 errors
# Epoch 6490: 2 errors
# Epoch 6500: 2 errors
# Epoch 6510: 2 errors
# Epoch 6520: 2 errors
# Epoch 6530: 2 errors
# Epoch 6540: 2 errors
# Epoch 6550: 2 errors
# Epoch 6560: 2 errors
# Epoch 6570: 2 errors
# Epoch 6580: 2 errors
# Epoch 6590: 2 errors
# Epoch 6600: 2 errors
# Epoch 6610: 2 errors
# Epoch 6620: 2 errors
# Epoch 6630: 2 errors
# Epoch 6640: 2 errors
# Epoch 6650: 2 errors
# Epoch 6660: 2 errors
# Epoch 6670: 2 errors
# Epoch 6680: 2 errors
# Epoch 6690: 2 errors
# Epoch 6700: 2 errors
# Epoch 6710: 2 errors
# Epoch 6720: 2 errors
# Epoch 6730: 2 errors
# Epoch 6740: 2 errors
# Epoch 6750: 2 errors
# Epoch 6760: 2 errors
# Epoch 6770: 2 errors
# Epoch 6780: 2 errors
# Epoch 6790: 1 errors
# Epoch 6800: 2 errors
# Epoch 6810: 2 errors
# Epoch 6820: 2 errors
# Epoch 6830: 2 errors
# Epoch 6840: 2 errors
# Epoch 6850: 2 errors
# Epoch 6860: 2 errors
# Epoch 6870: 2 errors
# Epoch 6880: 2 errors
# Epoch 6890: 2 errors
# Epoch 6900: 2 errors
# Epoch 6910: 2 errors
# Epoch 6920: 2 errors
# Epoch 6930: 2 errors
# Epoch 6940: 1 errors
# Epoch 6950: 2 errors
# Epoch 6960: 2 errors
# Epoch 6970: 2 errors
# Epoch 6980: 2 errors
# Epoch 6990: 2 errors
# Epoch 7000: 2 errors
# Epoch 7010: 2 errors
# Epoch 7020: 2 errors
# Epoch 7030: 2 errors
# Epoch 7040: 2 errors
# Epoch 7050: 2 errors
# Epoch 7060: 2 errors
# Epoch 7070: 2 errors
# Epoch 7080: 2 errors
# Epoch 7090: 1 errors
# Epoch 7100: 2 errors
# Epoch 7110: 2 errors
# Epoch 7120: 2 errors
# Epoch 7130: 2 errors
# Epoch 7140: 2 errors
# Epoch 7150: 2 errors
# Epoch 7160: 2 errors
# Epoch 7170: 2 errors
# Epoch 7180: 2 errors
# Epoch 7190: 2 errors
# Epoch 7200: 2 errors
# Epoch 7210: 2 errors
# Epoch 7220: 2 errors
# Epoch 7230: 2 errors
# Epoch 7240: 1 errors
# Epoch 7250: 2 errors
# Epoch 7260: 2 errors
# Epoch 7270: 2 errors
# Epoch 7280: 2 errors
# Epoch 7290: 2 errors
# Epoch 7300: 2 errors
# Epoch 7310: 2 errors
# Epoch 7320: 2 errors
# Epoch 7330: 2 errors
# Epoch 7340: 2 errors
# Epoch 7350: 2 errors
# Epoch 7360: 2 errors
# Epoch 7370: 2 errors
# Epoch 7380: 2 errors
# Epoch 7390: 1 errors
# Epoch 7400: 2 errors
# Epoch 7410: 2 errors
# Epoch 7420: 2 errors
# Epoch 7430: 2 errors
# Epoch 7440: 2 errors
# Epoch 7450: 2 errors
# Epoch 7460: 2 errors
# Epoch 7470: 2 errors
# Epoch 7480: 2 errors
# Epoch 7490: 2 errors
# Epoch 7500: 2 errors
# Epoch 7510: 2 errors
# Epoch 7520: 2 errors
# Epoch 7530: 2 errors
# Epoch 7540: 1 errors
# Epoch 7550: 2 errors
# Epoch 7560: 2 errors
# Epoch 7570: 2 errors
# Epoch 7580: 2 errors
# Epoch 7590: 2 errors
# Epoch 7600: 2 errors
# Epoch 7610: 2 errors
# Epoch 7620: 2 errors
# Epoch 7630: 2 errors
# Epoch 7640: 2 errors
# Epoch 7650: 2 errors
# Epoch 7660: 2 errors
# Epoch 7670: 2 errors
# Epoch 7680: 2 errors
# Epoch 7690: 2 errors
# Epoch 7700: 2 errors
# Epoch 7710: 2 errors
# Epoch 7720: 2 errors
# Epoch 7730: 2 errors
# Epoch 7740: 2 errors
# Epoch 7750: 2 errors
# Epoch 7760: 2 errors
# Epoch 7770: 2 errors
# Epoch 7780: 2 errors
# Epoch 7790: 2 errors
# Epoch 7800: 2 errors
# Epoch 7810: 2 errors
# Epoch 7820: 2 errors
# Epoch 7830: 2 errors
# Epoch 7840: 2 errors
# Epoch 7850: 2 errors
# Epoch 7860: 1 errors
# Epoch 7870: 2 errors
# Epoch 7880: 2 errors
# Epoch 7890: 2 errors
# Epoch 7900: 2 errors
# Epoch 7910: 2 errors
# Epoch 7920: 2 errors
# Epoch 7930: 2 errors
# Epoch 7940: 2 errors
# Epoch 7950: 2 errors
# Epoch 7960: 2 errors
# Epoch 7970: 2 errors
# Epoch 7980: 2 errors
# Epoch 7990: 2 errors
# Epoch 8000: 2 errors
# Epoch 8010: 1 errors
# Epoch 8020: 2 errors
# Epoch 8030: 2 errors
# Epoch 8040: 2 errors
# Epoch 8050: 2 errors
# Epoch 8060: 2 errors
# Epoch 8070: 2 errors
# Epoch 8080: 2 errors
# Epoch 8090: 2 errors
# Epoch 8100: 2 errors
# Epoch 8110: 2 errors
# Epoch 8120: 2 errors
# Epoch 8130: 2 errors
# Epoch 8140: 2 errors
# Epoch 8150: 2 errors
# Epoch 8160: 1 errors
# Epoch 8170: 2 errors
# Epoch 8180: 2 errors
# Epoch 8190: 2 errors
# Epoch 8200: 2 errors
# Epoch 8210: 2 errors
# Epoch 8220: 2 errors
# Epoch 8230: 2 errors
# Epoch 8240: 2 errors
# Epoch 8250: 2 errors
# Epoch 8260: 2 errors
# Epoch 8270: 2 errors
# Epoch 8280: 2 errors
# Epoch 8290: 2 errors
# Epoch 8300: 2 errors
# Epoch 8310: 1 errors
# Epoch 8320: 2 errors
# Epoch 8330: 2 errors
# Epoch 8340: 2 errors
# Epoch 8350: 2 errors
# Epoch 8360: 2 errors
# Epoch 8370: 2 errors
# Epoch 8380: 2 errors
# Epoch 8390: 2 errors
# Epoch 8400: 2 errors
# Epoch 8410: 2 errors
# Epoch 8420: 2 errors
# Epoch 8430: 2 errors
# Epoch 8440: 2 errors
# Epoch 8450: 2 errors
# Epoch 8460: 1 errors
# Epoch 8470: 2 errors
# Epoch 8480: 2 errors
# Epoch 8490: 2 errors
# Epoch 8500: 2 errors
# Epoch 8510: 2 errors
# Epoch 8520: 2 errors
# Epoch 8530: 2 errors
# Epoch 8540: 2 errors
# Epoch 8550: 2 errors
# Epoch 8560: 2 errors
# Epoch 8570: 2 errors
# Epoch 8580: 2 errors
# Epoch 8590: 2 errors
# Epoch 8600: 2 errors
# Epoch 8610: 1 errors
# Epoch 8620: 2 errors
# Epoch 8630: 2 errors
# Epoch 8640: 2 errors
# Epoch 8650: 2 errors
# Epoch 8660: 2 errors
# Epoch 8670: 2 errors
# Epoch 8680: 2 errors
# Epoch 8690: 2 errors
# Epoch 8700: 2 errors
# Epoch 8710: 2 errors
# Epoch 8720: 2 errors
# Epoch 8730: 2 errors
# Epoch 8740: 2 errors
# Epoch 8750: 2 errors
# Epoch 8760: 2 errors
# Epoch 8770: 2 errors
# Epoch 8780: 2 errors
# Epoch 8790: 2 errors
# Epoch 8800: 2 errors
# Epoch 8810: 2 errors
# Epoch 8820: 2 errors
# Epoch 8830: 2 errors
# Epoch 8840: 2 errors
# Epoch 8850: 2 errors
# Epoch 8860: 2 errors
# Epoch 8870: 2 errors
# Epoch 8880: 2 errors
# Epoch 8890: 2 errors
# Epoch 8900: 2 errors
# Epoch 8910: 2 errors
# Epoch 8920: 2 errors
# Epoch 8930: 1 errors
# Epoch 8940: 2 errors
# Epoch 8950: 2 errors
# Epoch 8960: 2 errors
# Epoch 8970: 2 errors
# Epoch 8980: 2 errors
# Epoch 8990: 2 errors
# Epoch 9000: 2 errors
# Epoch 9010: 2 errors
# Epoch 9020: 2 errors
# Epoch 9030: 2 errors
# Epoch 9040: 2 errors
# Epoch 9050: 2 errors
# Epoch 9060: 2 errors
# Epoch 9070: 2 errors
# Epoch 9080: 1 errors
# Epoch 9090: 2 errors
# Epoch 9100: 2 errors
# Epoch 9110: 2 errors
# Epoch 9120: 2 errors
# Epoch 9130: 2 errors
# Epoch 9140: 2 errors
# Epoch 9150: 2 errors
# Epoch 9160: 2 errors
# Epoch 9170: 2 errors
# Epoch 9180: 2 errors
# Epoch 9190: 2 errors
# Epoch 9200: 2 errors
# Epoch 9210: 2 errors
# Epoch 9220: 2 errors
# Epoch 9230: 1 errors
# Epoch 9240: 2 errors
# Epoch 9250: 2 errors
# Epoch 9260: 2 errors
# Epoch 9270: 2 errors
# Epoch 9280: 2 errors
# Epoch 9290: 2 errors
# Epoch 9300: 2 errors
# Epoch 9310: 2 errors
# Epoch 9320: 2 errors
# Epoch 9330: 2 errors
# Epoch 9340: 2 errors
# Epoch 9350: 2 errors
# Epoch 9360: 2 errors
# Epoch 9370: 2 errors
# Epoch 9380: 1 errors
# Epoch 9390: 2 errors
# Epoch 9400: 2 errors
# Epoch 9410: 2 errors
# Epoch 9420: 2 errors
# Epoch 9430: 2 errors
# Epoch 9440: 2 errors
# Epoch 9450: 2 errors
# Epoch 9460: 2 errors
# Epoch 9470: 2 errors
# Epoch 9480: 2 errors
# Epoch 9490: 2 errors
# Epoch 9500: 2 errors
# Epoch 9510: 2 errors
# Epoch 9520: 2 errors
# Epoch 9530: 1 errors
# Epoch 9540: 2 errors
# Epoch 9550: 2 errors
# Epoch 9560: 2 errors
# Epoch 9570: 2 errors
# Epoch 9580: 2 errors
# Epoch 9590: 2 errors
# Epoch 9600: 2 errors
# Epoch 9610: 2 errors
# Epoch 9620: 2 errors
# Epoch 9630: 2 errors
# Epoch 9640: 2 errors
# Epoch 9650: 2 errors
# Epoch 9660: 2 errors
# Epoch 9670: 2 errors
# Epoch 9680: 1 errors
# Epoch 9690: 2 errors
# Epoch 9700: 2 errors
# Epoch 9710: 2 errors
# Epoch 9720: 2 errors
# Epoch 9730: 2 errors
# Epoch 9740: 2 errors
# Epoch 9750: 2 errors
# Epoch 9760: 2 errors
# Epoch 9770: 2 errors
# Epoch 9780: 2 errors
# Epoch 9790: 2 errors
# Epoch 9800: 2 errors
# Epoch 9810: 2 errors
# Epoch 9820: 2 errors
# Epoch 9830: 2 errors
# Epoch 9840: 2 errors
# Epoch 9850: 2 errors
# Epoch 9860: 2 errors
# Epoch 9870: 2 errors
# Epoch 9880: 2 errors
# Epoch 9890: 2 errors
# Epoch 9900: 2 errors
# Epoch 9910: 2 errors
# Epoch 9920: 2 errors
# Epoch 9930: 2 errors
# Epoch 9940: 2 errors
# Epoch 9950: 2 errors
# Epoch 9960: 2 errors
# Epoch 9970: 2 errors
# Epoch 9980: 2 errors
# Epoch 9990: 2 errors
# Epoch 10000: 1 errors
# Epoch 10010: 2 errors
# Epoch 10020: 2 errors
# Epoch 10030: 2 errors
# Epoch 10040: 2 errors
# Epoch 10050: 2 errors
# Epoch 10060: 2 errors
# Epoch 10070: 2 errors
# Epoch 10080: 2 errors
# Epoch 10090: 2 errors
# Epoch 10100: 2 errors
# Epoch 10110: 2 errors
# Epoch 10120: 2 errors
# Epoch 10130: 2 errors
# Epoch 10140: 2 errors
# Epoch 10150: 1 errors
# Epoch 10160: 2 errors
# Epoch 10170: 2 errors
# Epoch 10180: 2 errors
# Epoch 10190: 2 errors
# Epoch 10200: 2 errors
# Epoch 10210: 2 errors
# Epoch 10220: 2 errors
# Epoch 10230: 2 errors
# Epoch 10240: 2 errors
# Epoch 10250: 2 errors
# Epoch 10260: 2 errors
# Epoch 10270: 2 errors
# Epoch 10280: 2 errors
# Epoch 10290: 2 errors
# Epoch 10300: 1 errors
# Epoch 10310: 2 errors
# Epoch 10320: 2 errors
# Epoch 10330: 2 errors
# Epoch 10340: 2 errors
# Epoch 10350: 2 errors
# Epoch 10360: 2 errors
# Epoch 10370: 2 errors
# Epoch 10380: 2 errors
# Epoch 10390: 2 errors
# Epoch 10400: 2 errors
# Epoch 10410: 2 errors
# Epoch 10420: 2 errors
# Epoch 10430: 2 errors
# Epoch 10440: 2 errors
# Epoch 10450: 1 errors
# Epoch 10460: 2 errors
# Epoch 10470: 2 errors
# Epoch 10480: 2 errors
# Epoch 10490: 2 errors
# Epoch 10500: 2 errors
# Epoch 10510: 2 errors
# Epoch 10520: 2 errors
# Epoch 10530: 2 errors
# Epoch 10540: 2 errors
# Epoch 10550: 2 errors
# Epoch 10560: 2 errors
# Epoch 10570: 2 errors
# Epoch 10580: 2 errors
# Epoch 10590: 2 errors
# Epoch 10600: 1 errors
# Epoch 10610: 2 errors
# Epoch 10620: 2 errors
# Epoch 10630: 2 errors
# Epoch 10640: 2 errors
# Epoch 10650: 2 errors
# Epoch 10660: 2 errors
# Epoch 10670: 2 errors
# Epoch 10680: 2 errors
# Epoch 10690: 2 errors
# Epoch 10700: 2 errors
# Epoch 10710: 2 errors
# Epoch 10720: 2 errors
# Epoch 10730: 2 errors
# Epoch 10740: 2 errors
# Epoch 10750: 1 errors
# Epoch 10760: 2 errors
# Epoch 10770: 2 errors
# Epoch 10780: 2 errors
# Epoch 10790: 2 errors
# Epoch 10800: 2 errors
# Epoch 10810: 2 errors
# Epoch 10820: 2 errors
# Epoch 10830: 2 errors
# Epoch 10840: 2 errors
# Epoch 10850: 2 errors
# Epoch 10860: 2 errors
# Epoch 10870: 2 errors
# Epoch 10880: 2 errors
# Epoch 10890: 2 errors
# Epoch 10900: 2 errors
# Epoch 10910: 2 errors
# Epoch 10920: 2 errors
# Epoch 10930: 2 errors
# Epoch 10940: 2 errors
# Epoch 10950: 2 errors
# Epoch 10960: 2 errors
# Epoch 10970: 2 errors
# Epoch 10980: 2 errors
# Epoch 10990: 2 errors
# Epoch 11000: 2 errors
# Epoch 11010: 2 errors
# Epoch 11020: 2 errors
# Epoch 11030: 2 errors
# Epoch 11040: 2 errors
# Epoch 11050: 2 errors
# Epoch 11060: 2 errors
# Epoch 11070: 1 errors
# Epoch 11080: 2 errors
# Epoch 11090: 2 errors
# Epoch 11100: 2 errors
# Epoch 11110: 2 errors
# Epoch 11120: 2 errors
# Epoch 11130: 2 errors
# Epoch 11140: 2 errors
# Epoch 11150: 2 errors
# Epoch 11160: 2 errors
# Epoch 11170: 2 errors
# Epoch 11180: 2 errors
# Epoch 11190: 2 errors
# Epoch 11200: 2 errors
# Epoch 11210: 2 errors
# Epoch 11220: 1 errors
# Epoch 11230: 2 errors
# Epoch 11240: 2 errors
# Epoch 11250: 2 errors
# Epoch 11260: 2 errors
# Epoch 11270: 2 errors
# Epoch 11280: 2 errors
# Epoch 11290: 2 errors
# Epoch 11300: 2 errors
# Epoch 11310: 2 errors
# Epoch 11320: 2 errors
# Epoch 11330: 2 errors
# Epoch 11340: 2 errors
# Epoch 11350: 2 errors
# Epoch 11360: 2 errors
# Epoch 11370: 1 errors
# Epoch 11380: 2 errors
# Epoch 11390: 2 errors
# Epoch 11400: 2 errors
# Epoch 11410: 2 errors
# Epoch 11420: 2 errors
# Epoch 11430: 2 errors
# Epoch 11440: 2 errors
# Epoch 11450: 2 errors
# Epoch 11460: 2 errors
# Epoch 11470: 2 errors
# Epoch 11480: 2 errors
# Epoch 11490: 2 errors
# Epoch 11500: 2 errors
# Epoch 11510: 2 errors
# Epoch 11520: 1 errors
# Epoch 11530: 2 errors
# Epoch 11540: 2 errors
# Epoch 11550: 2 errors
# Epoch 11560: 2 errors
# Epoch 11570: 2 errors
# Epoch 11580: 2 errors
# Epoch 11590: 2 errors
# Epoch 11600: 2 errors
# Epoch 11610: 2 errors
# Epoch 11620: 2 errors
# Epoch 11630: 2 errors
# Epoch 11640: 2 errors
# Epoch 11650: 2 errors
# Epoch 11660: 2 errors
# Epoch 11670: 1 errors
# Epoch 11680: 2 errors
# Epoch 11690: 2 errors
# Epoch 11700: 2 errors
# Epoch 11710: 2 errors
# Epoch 11720: 2 errors
# Epoch 11730: 2 errors
# Epoch 11740: 2 errors
# Epoch 11750: 2 errors
# Epoch 11760: 2 errors
# Epoch 11770: 2 errors
# Epoch 11780: 2 errors
# Epoch 11790: 2 errors
# Epoch 11800: 2 errors
# Epoch 11810: 2 errors
# Epoch 11820: 1 errors
# Epoch 11830: 2 errors
# Epoch 11840: 2 errors
# Epoch 11850: 2 errors
# Epoch 11860: 2 errors
# Epoch 11870: 2 errors
# Epoch 11880: 2 errors
# Epoch 11890: 2 errors
# Epoch 11900: 2 errors
# Epoch 11910: 2 errors
# Epoch 11920: 2 errors
# Epoch 11930: 2 errors
# Epoch 11940: 2 errors
# Epoch 11950: 2 errors
# Epoch 11960: 2 errors
# Epoch 11970: 2 errors
# Epoch 11980: 2 errors
# Epoch 11990: 2 errors
# Epoch 12000: 2 errors
# Epoch 12010: 2 errors
# Epoch 12020: 2 errors
# Epoch 12030: 2 errors
# Epoch 12040: 2 errors
# Epoch 12050: 2 errors
# Epoch 12060: 2 errors
# Epoch 12070: 2 errors
# Epoch 12080: 2 errors
# Epoch 12090: 2 errors
# Epoch 12100: 2 errors
# Epoch 12110: 2 errors
# Epoch 12120: 2 errors
# Epoch 12130: 2 errors
# Epoch 12140: 1 errors
# Epoch 12150: 2 errors
# Epoch 12160: 2 errors
# Epoch 12170: 2 errors
# Epoch 12180: 2 errors
# Epoch 12190: 2 errors
# Epoch 12200: 2 errors
# Epoch 12210: 2 errors
# Epoch 12220: 2 errors
# Epoch 12230: 2 errors
# Epoch 12240: 2 errors
# Epoch 12250: 2 errors
# Epoch 12260: 2 errors
# Epoch 12270: 2 errors
# Epoch 12280: 2 errors
# Epoch 12290: 1 errors
# Epoch 12300: 2 errors
# Epoch 12310: 2 errors
# Epoch 12320: 2 errors
# Epoch 12330: 2 errors
# Epoch 12340: 2 errors
# Epoch 12350: 2 errors
# Epoch 12360: 2 errors
# Epoch 12370: 2 errors
# Epoch 12380: 2 errors
# Epoch 12390: 2 errors
# Epoch 12400: 2 errors
# Epoch 12410: 2 errors
# Epoch 12420: 2 errors
# Epoch 12430: 2 errors
# Epoch 12440: 1 errors
# Epoch 12450: 2 errors
# Epoch 12460: 2 errors
# Epoch 12470: 2 errors
# Epoch 12480: 2 errors
# Epoch 12490: 2 errors
# Epoch 12500: 2 errors
# Epoch 12510: 2 errors
# Epoch 12520: 2 errors
# Epoch 12530: 2 errors
# Epoch 12540: 2 errors
# Epoch 12550: 2 errors
# Epoch 12560: 2 errors
# Epoch 12570: 2 errors
# Epoch 12580: 2 errors
# Epoch 12590: 1 errors
# Epoch 12600: 2 errors
# Epoch 12610: 2 errors
# Epoch 12620: 2 errors
# Epoch 12630: 2 errors
# Epoch 12640: 2 errors
# Epoch 12650: 2 errors
# Epoch 12660: 2 errors
# Epoch 12670: 2 errors
# Epoch 12680: 2 errors
# Epoch 12690: 2 errors
# Epoch 12700: 2 errors
# Epoch 12710: 2 errors
# Epoch 12720: 2 errors
# Epoch 12730: 2 errors
# Epoch 12740: 1 errors
# Epoch 12750: 2 errors
# Epoch 12760: 2 errors
# Epoch 12770: 2 errors
# Epoch 12780: 2 errors
# Epoch 12790: 2 errors
# Epoch 12800: 2 errors
# Epoch 12810: 2 errors
# Epoch 12820: 2 errors
# Epoch 12830: 2 errors
# Epoch 12840: 2 errors
# Epoch 12850: 2 errors
# Epoch 12860: 2 errors
# Epoch 12870: 2 errors
# Epoch 12880: 2 errors
# Epoch 12890: 1 errors
# Epoch 12900: 2 errors
# Epoch 12910: 2 errors
# Epoch 12920: 2 errors
# Epoch 12930: 2 errors
# Epoch 12940: 2 errors
# Epoch 12950: 2 errors
# Epoch 12960: 2 errors
# Epoch 12970: 2 errors
# Epoch 12980: 2 errors
# Epoch 12990: 2 errors
# Epoch 13000: 2 errors
# Epoch 13010: 2 errors
# Epoch 13020: 2 errors
# Epoch 13030: 2 errors
# Epoch 13040: 2 errors
# Epoch 13050: 2 errors
# Epoch 13060: 2 errors
# Epoch 13070: 2 errors
# Epoch 13080: 2 errors
# Epoch 13090: 2 errors
# Epoch 13100: 2 errors
# Epoch 13110: 2 errors
# Epoch 13120: 2 errors
# Epoch 13130: 2 errors
# Epoch 13140: 2 errors
# Epoch 13150: 2 errors
# Epoch 13160: 2 errors
# Epoch 13170: 2 errors
# Epoch 13180: 2 errors
# Epoch 13190: 2 errors
# Epoch 13200: 2 errors
# Epoch 13210: 2 errors

# %% [markdown]
# ### c) Training procedure visualization

# %%
def draw_num_errors(ax, performance, epoch):
    epochs = [elem[0] for elem in performance[:epoch + 1]]
    epoch_errors = [elem[1] for elem in performance[:epoch + 1]]

    ax.plot(epochs, epoch_errors)
    ax.set_xlim([0, len(performance)])
    ax.set_title('Errors as a function of epochs')
    ax.set_xlabel('epoch')
    ax.set_ylabel('classification errors')


def draw_decision_boundary(ax, performance, epoch, wine_data, features):
    x_min = wine_data.loc[:, features[0]].min() - 0.15
    x_max = wine_data.loc[:, features[0]].max() + 0.15
    y_min = wine_data.loc[:, features[1]].min() - 0.15
    y_max = wine_data.loc[:, features[1]].max() + 0.15
    
    ax.set_title('Decision boundary at epoch {}'.format(epoch))
    ax.set_xlabel(features[0])
    ax.set_xlim([x_min, x_max])
    ax.set_ylabel(features[1])
    ax.set_ylim([y_min, y_max])
    
    w2, w1 = performance[epoch][2]
    b = performance[epoch][3]
    slope = -w1/w2
    intercept = -b/w2
    x_coords = range(int(x_min) - 1, int(x_max) + 2)
    y_coords = slope * x_coords + intercept

    ax.plot(x_coords, y_coords, 'b--', label='Decision boundary')
    ax.fill_between(x_coords, y_coords, y_min, color='#99ff99')
    ax.fill_between(x_coords, y_coords, y_max, color='#ff9999')


def draw_scatter(ax, wine_data, features, good_thresh, bad_thresh):
    good_wines = wine_data[(wine_data['quality'] > good_thresh)]
    bad_wines = wine_data[(wine_data['quality'] < bad_thresh)]

    ax.scatter(good_wines.loc[:, features[0]], good_wines.loc[:, features[1]],
                    c=['g'], label='good wines (> {} score)'.format(good_thresh))
    ax.scatter(bad_wines.loc[:, features[0]], bad_wines.loc[:, features[1]],
                    c=['r'], label='bad wines (< {} score)'.format(bad_thresh))
    ax.legend(bbox_to_anchor=(1.05, 1), loc=2)

    
def plot_performance(performance, wine_data, features, good_thresh, bad_thresh,
                     epoch=-1, save_plot=False, save_name='./train_stats.png'):
    """
    Plot the performance of perceptron or adaline.
    This function will produce a two plot figure:
    1) Number of classification errors as a function of epochs
    2) Decision boundary for two factors
    """
    fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(15,5))
    
    if epoch > len(performance) - 1:
        raise ValueError('number of epochs should be less than {}'.format(len(performance)))
    
    if len(features) != 2:
        raise ValueError('number of features should be 2')
    
    if epoch == -1:
        epoch = len(performance) - 1

    draw_num_errors(axes[0], performance, epoch)    
    draw_decision_boundary(axes[1], performance, epoch, wine_data, features)
    draw_scatter(axes[1], wine_data, features, good_thresh, bad_thresh)
    
    if save_plot:
        plt.savefig(save_name)
    
    return fig

# %% [markdown]
# ---
# # VI.2 Do perceptrons dream of electric sheep?

# %%
def save_animation(performance, data, features, good_thresh, bad_thresh,
                   num_frames=-1, name='performance_animation.html'):
    if len(features) != 2:
        raise ValueError('number of features should be 2')
    
    if num_frames > len(performance) - 1:
            raise ValueError('num_frames should be less than {}'.format(len(performance)))
    
    if num_frames == -1:
        num_frames = len(performance) - 1

    fig = plt.figure(figsize=(15,5), dpi=150)
    ax = plt.gca()
    ax.xaxis.set_visible(False)
    ax.yaxis.set_visible(False)

    def init():
        imobj.set_data(array_init((360, 1000), mode='zeros'))

        return imobj,

    def animate(i, performance, data, features, good_thresh, bad_thresh):
        fname = './train_stats_{}.png'.format(i)
        plot_performance(performance, data, features, good_thresh, bad_thresh,
                                   epoch=i, save_plot=True, save_name=fname)
        img = mpimg.imread(fname)[-1::-1]
        imobj.set_data(img)
        os.remove(fname)

        return imobj,

    imobj = ax.imshow(array_init((360, 1000), mode='zeros'), interpolation='bilinear',
                      origin='lower', alpha=1.0, zorder=1, aspect=1)

    anim = animation.FuncAnimation(fig, animate, init_func=init,
                                   fargs=(performance, data, features, good_thresh, bad_thresh),
                                   repeat=False, frames=range(num_frames),
                                   interval=120, blit=True)
    anim.save(name)
    print('[+] Animation saved as {}'.format(name))

# %%
save_animation(train_stats, selected_wine_data, ['alcohol', 'volatile acidity'], 7, 4, num_frames=50)
# Out:
# MovieWriter ffmpeg unavailable.
# /anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py:522: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /anaconda3/lib/python3.7/site-packages/PIL/Image.py in save(self, fp, format, **params)
#    1929             try:
# -> 1930                 format = EXTENSION[ext]
#    1931             except KeyError:
#
# KeyError: '.html'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-23-b6eb856ac5f5> in <module>()
# ----> 1 save_animation(train_stats, selected_wine_data, ['alcohol', 'volatile acidity'], 7, 4, num_frames=50)
#
# <ipython-input-22-38dde6a93abe> in save_animation(performance, data, features, good_thresh, bad_thresh, num_frames, name)
#      37                                    repeat=False, frames=range(num_frames),
#      38                                    interval=120, blit=True)
# ---> 39     anim.save(name)
#      40     print('[+] Animation saved as {}'.format(name))
#
# /anaconda3/lib/python3.7/site-packages/matplotlib/animation.py in save(self, filename, writer, fps, dpi, codec, bitrate, extra_args, metadata, extra_anim, savefig_kwargs)
#    1198                         # TODO: See if turning off blit is really necessary
#    1199                         anim._draw_next_frame(d, blit=False)
# -> 1200                     writer.grab_frame(**savefig_kwargs)
#    1201
#    1202         # Reconnect signal for first draw if necessary
#
# /anaconda3/lib/python3.7/contextlib.py in __exit__(self, type, value, traceback)
#     117         if type is None:
#     118             try:
# --> 119                 next(self.gen)
#     120             except StopIteration:
#     121                 return False
#
# /anaconda3/lib/python3.7/site-packages/matplotlib/animation.py in saving(self, fig, outfile, dpi, *args, **kwargs)
#     239             yield self
#     240         finally:
# --> 241             self.finish()
#     242
#     243
#
# /anaconda3/lib/python3.7/site-packages/matplotlib/animation.py in finish(self)
#     610         self._frames[0].save(
#     611             self._outfile, save_all=True, append_images=self._frames[1:],
# --> 612             duration=int(1000 / self.fps))
#     613
#     614
#
# /anaconda3/lib/python3.7/site-packages/PIL/Image.py in save(self, fp, format, **params)
#    1930                 format = EXTENSION[ext]
#    1931             except KeyError:
# -> 1932                 raise ValueError('unknown file extension: {}'.format(ext))
#    1933
#    1934         if format.upper() not in SAVE:
#
# ValueError: unknown file extension: .html

# %% [markdown]
# ---

# %%
fig = plot_performance(train_stats, selected_wine_data, ['alcohol', 'pH'], 7, 4, -1, False)
plt.show(fig)

# %% [markdown]
# ### d) Feature Scaling
#
# x* = (x - average(x)) / (max(x) - min(x))

# %%
def normalize_series(series):
    """
    Perform mean normalization of pandas.Series
    """

    if not isinstance(series, pd.Series):
        raise ValueError('input argument is not an instance of pandas.Series class')

    return (series - series.mean()) / (series.max() - series.min())

# %%
selected_wine_data['volatile acidity'] = normalize_series(selected_wine_data['volatile acidity'])
selected_wine_data['alcohol'] = normalize_series(selected_wine_data['alcohol'])

X = selected_wine_data.loc[:, ['volatile acidity', 'alcohol']]
Y = selected_wine_data['goodness'].values

# %%
p = Perceptron(lr=0.005)

train_stats = p.train(X.values, Y, 0, verbose=True, seed=1699)
# Out:
# Epoch 0: 4 errors

# %%
fig = plot_performance(train_stats, selected_wine_data, ['alcohol', 'volatile acidity'], 7, 4, -1, False)
plt.show(fig)

# %%
save_animation(train_stats, selected_wine_data, ['alcohol', 'pH'], 7, 4, num_frames=-1)

# %% [markdown]
# ----------------------------------
# # V.3 My fair ADALINE

# %% [markdown]
# ### a) Marvin notices and chides you for torturing your perceptron. Why?
#
# Let's try to distinguish between wines with a score of 4 and lower, and wines with a score of 7 and higher. We'll see, that perceptron learns shit on this data.
#
# It happens because single layer perceptrons are only capable of learning linearly separable patterns. The perceptron learning algorithm does not terminate if the learning set is not linearly separable, it will just never reach a point where all vectors are classified properly.

# %%
features = ['pH', 'alcohol', 'quality', 'goodness']
selected_wine_data = wine_data[(wine_data['quality'] > 7) | (wine_data['quality'] < 4)][features]
selected_wine_data = selected_wine_data.reset_index(drop=True)

selected_wine_data['pH'] = normalize_series(selected_wine_data['pH'])
selected_wine_data['alcohol'] = normalize_series(selected_wine_data['alcohol'])

X = selected_wine_data.loc[:, ['pH', 'alcohol']]
Y = selected_wine_data['goodness']

print('{} samples selected:\n'.format(X.shape[0]))
print(X[:10])
print('...')
# Out:
# 28 samples selected:
#
#          pH   alcohol
# 0  0.042942  0.262436
# 1 -0.099915  0.226722
# 2  0.292942  0.280293
# 3 -0.516582 -0.273278
# 4 -0.111820  0.369579
# 5 -0.076105 -0.416135
# 6 -0.195153  0.066008
# 7 -0.195153 -0.058992
# 8 -0.195153 -0.058992
# 9 -0.183248 -0.523278
# ...

# %%
p = Perceptron(lr=0.001)

train_stats = p.train(X.values, Y, 1000, verbose=True)
# Out:
# Epoch 0: 7 errors
# Epoch 10: 2 errors
# Epoch 20: 2 errors
# Epoch 30: 0 errors
# Epoch 40: 0 errors
# Epoch 50: 0 errors
# Epoch 60: 0 errors
# Epoch 70: 0 errors
# Epoch 80: 0 errors
# Epoch 90: 0 errors
# Epoch 100: 0 errors
# Epoch 110: 0 errors
# Epoch 120: 0 errors
# Epoch 130: 0 errors
# Epoch 140: 0 errors
# Epoch 150: 0 errors
# Epoch 160: 0 errors
# Epoch 170: 0 errors
# Epoch 180: 0 errors
# Epoch 190: 0 errors
# Epoch 200: 0 errors
# Epoch 210: 0 errors
# Epoch 220: 0 errors
# Epoch 230: 0 errors
# Epoch 240: 0 errors
# Epoch 250: 0 errors
# Epoch 260: 0 errors
# Epoch 270: 0 errors
# Epoch 280: 0 errors
# Epoch 290: 0 errors
# Epoch 300: 0 errors
# Epoch 310: 0 errors
# Epoch 320: 0 errors
# Epoch 330: 0 errors
# Epoch 340: 0 errors
# Epoch 350: 0 errors
# Epoch 360: 0 errors
# Epoch 370: 0 errors
# Epoch 380: 0 errors
# Epoch 390: 0 errors
# Epoch 400: 0 errors
# Epoch 410: 0 errors
# Epoch 420: 0 errors
# Epoch 430: 0 errors
# Epoch 440: 0 errors
# Epoch 450: 0 errors
# Epoch 460: 0 errors
# Epoch 470: 0 errors
# Epoch 480: 0 errors
# Epoch 490: 0 errors
# Epoch 500: 0 errors
# Epoch 510: 0 errors
# Epoch 520: 0 errors
# Epoch 530: 0 errors
# Epoch 540: 0 errors
# Epoch 550: 0 errors
# Epoch 560: 0 errors
# Epoch 570: 0 errors
# Epoch 580: 0 errors
# Epoch 590: 0 errors
# Epoch 600: 0 errors
# Epoch 610: 0 errors
# Epoch 620: 0 errors
# Epoch 630: 0 errors
# Epoch 640: 0 errors
# Epoch 650: 0 errors
# Epoch 660: 0 errors
# Epoch 670: 0 errors
# Epoch 680: 0 errors
# Epoch 690: 0 errors
# Epoch 700: 0 errors
# Epoch 710: 0 errors
# Epoch 720: 0 errors
# Epoch 730: 0 errors
# Epoch 740: 0 errors
# Epoch 750: 0 errors
# Epoch 760: 0 errors
# Epoch 770: 0 errors
# Epoch 780: 0 errors
# Epoch 790: 0 errors
# Epoch 800: 0 errors
# Epoch 810: 0 errors
# Epoch 820: 0 errors
# Epoch 830: 0 errors
# Epoch 840: 0 errors
# Epoch 850: 0 errors
# Epoch 860: 0 errors
# Epoch 870: 0 errors
# Epoch 880: 0 errors
# Epoch 890: 0 errors
# Epoch 900: 0 errors
# Epoch 910: 0 errors
# Epoch 920: 0 errors
# Epoch 930: 0 errors
# Epoch 940: 0 errors
# Epoch 950: 0 errors
# Epoch 960: 0 errors
# Epoch 970: 0 errors
# Epoch 980: 0 errors
# Epoch 990: 0 errors

# %%
fig = plot_performance(train_stats, selected_wine_data, ['alcohol', 'volatile acidity'], 6, 5, -1, False)
plt.show(fig)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in _validate_key(self, key, axis)
#    1789                 if not ax.contains(key):
# -> 1790                     error()
#    1791             except TypeError as e:
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in error()
#    1784                                .format(key=key,
# -> 1785                                        axis=self.obj._get_axis_name(axis)))
#    1786
#
# KeyError: 'the label [volatile acidity] is not in the [columns]'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-37-7941577b8053> in <module>()
# ----> 1 fig = plot_performance(train_stats, selected_wine_data, ['alcohol', 'volatile acidity'], 6, 5, -1, False)
#       2 plt.show(fig)
#
# <ipython-input-11-39f46fa23e6e> in plot_performance(performance, wine_data, features, good_thresh, bad_thresh, epoch, save_plot, save_name)
#      65
#      66     draw_num_errors(axes[0], performance, epoch)
# ---> 67     draw_decision_boundary(axes[1], performance, epoch, wine_data, features)
#      68     draw_scatter(axes[1], wine_data, features, good_thresh, bad_thresh)
#      69
#
# <ipython-input-11-39f46fa23e6e> in draw_decision_boundary(ax, performance, epoch, wine_data, features)
#      13     x_min = wine_data.loc[:, features[0]].min() - 0.15
#      14     x_max = wine_data.loc[:, features[0]].max() + 0.15
# ---> 15     y_min = wine_data.loc[:, features[1]].min() - 0.15
#      16     y_max = wine_data.loc[:, features[1]].max() + 0.15
#      17
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1470             except (KeyError, IndexError):
#    1471                 pass
# -> 1472             return self._getitem_tuple(key)
#    1473         else:
#    1474             # we by definition only have the 0th axis
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in _getitem_tuple(self, tup)
#     868     def _getitem_tuple(self, tup):
#     869         try:
# --> 870             return self._getitem_lowerdim(tup)
#     871         except IndexingError:
#     872             pass
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in _getitem_lowerdim(self, tup)
#     996         for i, key in enumerate(tup):
#     997             if is_label_like(key) or isinstance(key, tuple):
# --> 998                 section = self._getitem_axis(key, axis=i)
#     999
#    1000                 # we have yielded a scalar ?
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1909
#    1910         # fall thru to straight lookup
# -> 1911         self._validate_key(key, axis)
#    1912         return self._get_label(key, axis=axis)
#    1913
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in _validate_key(self, key, axis)
#    1796                 raise
#    1797             except:
# -> 1798                 error()
#    1799
#    1800     def _is_scalar_access(self, key):
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in error()
#    1783                 raise KeyError(u"the label [{key}] is not in the [{axis}]"
#    1784                                .format(key=key,
# -> 1785                                        axis=self.obj._get_axis_name(axis)))
#    1786
#    1787             try:
#
# KeyError: 'the label [volatile acidity] is not in the [columns]'

# %% [markdown]
# ### b) & c) Implementing ADALINE (Adaptive Linear Neuron)
#
# Adaline is similar to Perceptron and also belongs to the class of single layer binary classifiers. But there are some differences:
# - Adaline cost function is Sum Squared Error (SSE) instead of normal error of each training sample in Perceptron;
# - Adaline tries to minimize the cost function using Gradient Descent in contrast to Perceptron learning rule. This is an advantage of Adaline as it allows to calculate the error based on continous values rather than binary value;

# %%
class Adaline(object):

    def __init__(self, lr):
        self.W = None
        self.lr = lr
        self.performance = []

    def _net_input(self, X):
        """
        Linear model output: y = W.T * X + b
        """
        return ft_dot(self.W[1:], X) + self.W[0]
    
    def _activation_function(self, X):
        net_input = self._net_input(X)
        return 1 / (1 + math.exp(-net_input))
    
    def predict(self, X):
        """
        Mapping the net input to binary class value using unit (heaviside) step function
        """
        return 1 if self._activation_function(X) > 0.5 else 0
    
    def evaluate_accuracy(self, X, y):
        num_correct = 0

        for xi, yi in zip(X, y):
            num_correct += int(self.predict(xi) == int(yi))
        
        accuracy = num_correct / len(y)
        print('[.] Model accuracy: {0:.3f}'.format(accuracy))
        
        return accuracy
    
    def _eval_epoch(self, X, y, epoch):
        num_missclass = 0

        for xi, yi in zip(X, y):
            num_missclass += int(self.predict(xi) != int(yi))

        return num_missclass
    
    def _train_epoch(self, X, y, epoch, mode, verbose):
        epoch_errors = []

        for xi, yi in zip(X, y):
            error = yi - self._activation_function(xi)
            epoch_errors.append(error)

            if mode == 'stochastic':
                self.W[0] += self.lr * error
                self.W[1:] += self.lr * error * xi

        if mode == 'batch':
            self.W[0] += self.lr * sum(epoch_errors)
            self.W[1:] += self.lr * ft_dot(X, epoch_errors)

        num_missclass = self._eval_epoch(X, y, epoch)
        if verbose and epoch % 10 == 0:
            print('Epoch {}: {} errors'.format(epoch, num_missclass))
        self.performance.append((epoch, num_missclass, self.W[1:], self.W[0]))
        
        return epoch_errors

    
    def train(self, X, y, epochs, mode='batch', verbose=False, seed=None):
        if epochs < 0:
            raise ValueError('invalid number of training epochs')
        
        if mode != 'stochastic' and mode != 'batch':
            raise ValueError('invalid training mode')

        if seed:
            random.seed(seed)
            
        if self.W is None:
            self.W = [0.0001 * random.uniform(-1, 1) for i in range(X.shape[1] + 1)]

        epoch = 0
        while True:
            epoch_errors = self._train_epoch(X, y, epoch, mode, verbose)
            epoch += 1
            if epochs != 0 and epoch == epochs:
                break
            elif epochs == 0 and epoch_errors == 0:
                break
        
        return self.performance

# %% [markdown]
# ### d) Find a good learning rate for your ADALINE

# %%
# trying random search for learning rate tuning

for n in range(10):
    lr = round(random.uniform(0.001, 0.05), 5)
    ad = Adaline(lr)
    
    train_stats = ad.train(X.values, Y, 300, 'batch', verbose=False)
    num_errors = [elem[1] for elem in train_stats]
    min_errors = min(num_errors)
    last_error = train_stats[-1][1]
    
    print('try: {}, lr: {}, last error: {}, {} min errors,'.format(n, lr, last_error, min_errors))
# Out:
# try: 0, lr: 0.04039, last error: 1, 1 min errors,
# try: 1, lr: 0.0346, last error: 3, 1 min errors,
# try: 2, lr: 0.00581, last error: 8, 1 min errors,
# try: 3, lr: 0.02909, last error: 2, 1 min errors,
# try: 4, lr: 0.01998, last error: 1, 1 min errors,
# try: 5, lr: 0.00641, last error: 7, 1 min errors,
# try: 6, lr: 0.01228, last error: 1, 1 min errors,
# try: 7, lr: 0.01032, last error: 9, 1 min errors,
# try: 8, lr: 0.04318, last error: 1, 1 min errors,
# try: 9, lr: 0.04997, last error: 1, 1 min errors,

# %%
ad = Adaline(lr=0.05)

train_stats = ad.train(X.values, Y, 301, 'batch', verbose=True)
# Out:
# Epoch 0: 10 errors
# Epoch 10: 2 errors
# Epoch 20: 10 errors
# Epoch 30: 18 errors
# Epoch 40: 10 errors
# Epoch 50: 7 errors
# Epoch 60: 8 errors
# Epoch 70: 10 errors
# Epoch 80: 12 errors
# Epoch 90: 10 errors
# Epoch 100: 2 errors
# Epoch 110: 10 errors
# Epoch 120: 11 errors
# Epoch 130: 10 errors
# Epoch 140: 17 errors
# Epoch 150: 10 errors
# Epoch 160: 8 errors
# Epoch 170: 15 errors
# Epoch 180: 10 errors
# Epoch 190: 10 errors
# Epoch 200: 15 errors
# Epoch 210: 3 errors
# Epoch 220: 2 errors
# Epoch 230: 3 errors
# Epoch 240: 2 errors
# Epoch 250: 3 errors
# Epoch 260: 2 errors
# Epoch 270: 3 errors
# Epoch 280: 2 errors
# Epoch 290: 3 errors
# Epoch 300: 2 errors

# %%
fig = plot_performance(train_stats, selected_wine_data, ['pH', 'alcohol'], 7, 4, -1, False)
plt.show(fig)

# %%
save_animation(train_stats, selected_wine_data, ['alcohol', 'volatile acidity'], 7, 4, num_frames=100)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-2101a04c471f> in <module>()
# ----> 1 save_animation(train_stats, selected_wine_data, ['alcohol', 'volatile acidity'], 7, 4, num_frames=100)
#
# NameError: name 'save_animation' is not defined

# %% [markdown]
# ---
# ## V.4 Advanced wine sampling and resampling

# %% [markdown]
# ### a) Write a function that uses the holdout method to partition the red wine data into a training and a validation set

# %%
def train_test_split(wine_data, test_size=0.7):
    train_set = wine_data.sample(frac=test_size)
    test_set = wine_data.drop(train_set.index)

    print('Train set size: {}'.format(train_set.shape[0]))
    print('Test set size: {}'.format(test_set.shape[0]))
    
    return (train_set, test_set)

# %%
train_set, test_set = train_test_split(selected_wine_data, test_size=0.7)
X_train = train_set.loc[:, ['volatile acidity', 'alcohol']]
Y_train = train_set['goodness']

X_test = test_set.loc[:, ['volatile acidity', 'alcohol']]
Y_test = test_set['goodness']

# %%
# testing our best model on test_set

ad.evaluate_accuracy(X_test.values, Y_test)

# %% [markdown]
# ### b) Write a function that generates a k-fold cross-validation dataset from the red wine data

# %%
def k_fold_split(data, k, shuffle=True):
    folds = []
    
    if shuffle:
        data = data.sample(frac=1).reset_index(drop=True)
    
    for i in range(k):
        fold_size = data.shape[0] // k + 1 if i < data.shape[0] % k else data.shape[0] // k
        test_data = data.iloc[i * fold_size: (i + 1) * fold_size, :]
        train_data = data.iloc[data.index.difference(test_data.index), :]
        folds.append((train_data, test_data))
    
    return folds

# %%
num_folds = 9
folds = k_fold_split(selected_wine_data, 9)

print('train, val lengths for {} folds: {}'.format(
    num_folds, [(len(train), len(val)) for train, val in folds]))

# %%
def visualize_folds(folds, features):
    fig, axes = plt.subplots(ncols=len(folds), figsize=(13,5))
    
    for i, fold in enumerate(folds):
        if i != 0:
            axes[i].yaxis.set_visible(False)
        axes[i].scatter(fold[0].loc[:, features[0]], fold[0].loc[:, features[1]],
                    c=['g'], label='training data')
        axes[i].scatter(fold[1].loc[:, features[0]], fold[1].loc[:, features[1]],
                        c=['r'], label='test data')
        
        axes[i].set_xlabel(features[0])
        axes[i].set_ylabel(features[1])
    
    axes[len(folds) - 1].legend(bbox_to_anchor=(1.05, 1), loc=2)
    
    return fig

# %%
fig = visualize_folds(folds, ['alcohol', 'volatile acidity'])
plt.show(fig)

# %% [markdown]
# ### c) ADALINE evaluation via k-fold cross-validation

# %%
def cross_validate_adaline(folds, features, lr=0.05, epochs=500, mode='batch', verbose=False):
    sum_accuracy = 0

    for i, fold in enumerate(folds):
        X_train = fold[0][features]
        Y_train = fold[0]['goodness']
        
        ad = Adaline(lr=lr)
        train_stats = ad.train(X_train.values, Y_train, epochs, mode, verbose)
        
        X_test = fold[1][features]
        Y_test = fold[1]['goodness']
        accuracy = ad.evaluate_accuracy(X_test.values, Y_test)
        sum_accuracy += accuracy
    
    print('=================================')
    print('Mean model accuracy: {0:.3f}'.format(sum_accuracy / len(folds)))
    print('=================================')

# %%
# Small learning rate and few epochs --> lower accuracy

cross_validate_adaline(folds, ['alcohol', 'volatile acidity'], lr=0.0005,
                       epochs=100, mode='batch', verbose=False)

# %%
# Good learning rate allows to train quickly and gives good accuracy

cross_validate_adaline(folds, ['alcohol', 'volatile acidity'], lr=0.05,
                       epochs=10, mode='batch', verbose=False)

# %%
# And training longer doesn't really help much

cross_validate_adaline(folds, ['alcohol', 'volatile acidity'], lr=0.05,
                       epochs=200, mode='batch', verbose=False)

# %%
# If learning rate is too big, we will overshoot the point of minimum
# and get lower accuracy

cross_validate_adaline(folds, ['alcohol', 'volatile acidity'], lr=0.5,
                       epochs=200, mode='batch', verbose=False)

# %%
# Optimal learning rate desn't change things too much

cross_validate_adaline(folds, ['alcohol', 'volatile acidity'], lr=0.096,
                       epochs=200, mode='batch', verbose=False)

# %% [markdown]
# ---
# ## V.5 adventures in the Nth dimension

# %% [markdown]
# ### a) Training on more chemical factors

# %%
features = ['pH', 'alcohol', 'sulphates', 'fixed acidity', 'volatile acidity', 'goodness', 'quality']
selected_wine_data = wine_data[(wine_data['quality'] > 6) | (wine_data['quality'] < 5)][features]
selected_wine_data = selected_wine_data.reset_index(drop=True)

norm_features = ['pH', 'alcohol', 'sulphates', 'fixed acidity', 'volatile acidity']
for feature in norm_features:
    selected_wine_data[feature] = normalize_series(selected_wine_data[feature])

print(selected_wine_data[:10])

# %%
folds = k_fold_split(selected_wine_data, 9)

# %%
# adding 'pH' to taining features

cross_validate_adaline(folds, ['alcohol', 'volatile acidity', 'pH'], lr=0.05,
                       epochs=200, mode='batch', verbose=False)

# %%
# 'pH' -> 'sulphates'

cross_validate_adaline(folds, ['alcohol', 'volatile acidity', 'sulphates'], lr=0.05,
                       epochs=200, mode='batch', verbose=False)

# %%
# + 'fixed acidity'

cross_validate_adaline(folds, ['alcohol', 'volatile acidity', 'fixed acidity', 'sulphates'], lr=0.05,
                       epochs=200, mode='batch', verbose=False)

# %%
# 'fixed acidity' -> 'pH'

cross_validate_adaline(folds, ['alcohol', 'volatile acidity', 'pH', 'sulphates'], lr=0.05,
                       epochs=200, mode='batch', verbose=False)

# %% [markdown]
# ### b) What does the decision boundary for N factors look like?
# Decision boundary for N factors is (N - 1) dimentional hyperplane

# %% [markdown]
# ---
# # V.6 Marvin's rebuttal
#
# Find a way to successfully classify the Pan-Galactic Gargle Blaster dataset.
# Show that your perceptron or ADALINE successfully classifies the Pan-Galactic Gargle Blaster data set by plotting the decision boundary and also show ‘good’ and ‘bad’ Gargle Blaster data points.

# %%
dataset_path = './resources/Pan Galactic Gargle Blaster.csv'

try:
    gargle_blaster_data = pd.read_csv(dataset_path, sep=';')
except FileNotFoundError:
    print('[-] Set `dataset_path` with correct value')

# %%
# Take the gargle blaster as good, if it's quality > 5
gargle_blaster_data = gargle_blaster_data.assign(goodness=pd.Series(gargle_blaster_data['quality'] > 5))

# normalize feature series
gargle_blaster_data['wonderflonium'] = normalize_series(gargle_blaster_data['wonderflonium'])
gargle_blaster_data['fallian marsh gas'] = normalize_series(gargle_blaster_data['fallian marsh gas'])

# %%
fig = plot_scatter_matrix(gargle_blaster_data, 6, 5, True)
plt.show(fig)

# %% [markdown]
# Data is not linearly separable, so neither Perceptron, nor ADALINE will not learn from it.
#
# The trick is to transform data points to polar coordinate system, where they will be perfectly separable with a line.

# %%
x1 = gargle_blaster_data.loc[:, 'wonderflonium']
x2 = gargle_blaster_data.loc[:, 'fallian marsh gas']

# compute r and phi, needed for polar coordinates and add them to DataFrame
gargle_blaster_data = gargle_blaster_data.assign(r=pd.Series(x1 * x1 + x2 * x2).pow(1./2))
gargle_blaster_data = gargle_blaster_data.assign(
    phi=pd.Series([math.atan2(x, y) for (x, y) in zip(x1, x2)]))

print(gargle_blaster_data.iloc[:10])
print('...')

# %%
train_set, test_set = train_test_split(gargle_blaster_data, test_size=0.7)

# %%
X_train = train_set[['r', 'phi']]
Y_train = train_set['goodness'].values

X_test = test_set[['r', 'phi']]
Y_test = test_set['goodness'].values

# %%
ad = Adaline(lr=0.005)

train_stats = ad.train(X_train.values, Y_train, 70, 'batch', verbose=True)

# %%
ad.evaluate_accuracy(X_test.values, Y_test)

# %%
fig = plot_performance(train_stats, train_set, ['phi', 'r'], 6, 5, -1, False)
plt.show(fig)
